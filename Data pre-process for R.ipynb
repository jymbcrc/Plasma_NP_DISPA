# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from matplotlib import pyplot
import matplotlib
import seaborn as sns
import re
import math

# %%
df=pd.read_csv(r'F:\\Seer_project\\R_data\\result_all_dataframe.csv')

# %%
df_dd=df[df['Cluster']=='DD'].iloc[:10,:]

# %%
df_np1=df[df['Cluster']=='NP1'].iloc[:10,:]

# %%
df_np1
# Out:
#     Cluster          ID                               Description GeneRatio  \
# 271     NP1  GO:0006959                   humoral immune response    41/154
# 272     NP1  GO:0007596                         blood coagulation    34/154
# 273     NP1  GO:0050817                               coagulation    34/154
# 274     NP1  GO:0007599                                hemostasis    34/154
# 275     NP1  GO:0006956                     complement activation    22/154
# 276     NP1  GO:0042730                              fibrinolysis    16/154
# 277     NP1  GO:0050878           regulation of body fluid levels    34/154
# 278     NP1  GO:0030195  negative regulation of blood coagulation    18/154
# 279     NP1  GO:1900047         negative regulation of hemostasis    18/154
# 280     NP1  GO:0050819        negative regulation of coagulation    18/154
#
#        BgRatio        pvalue      p.adjust        qvalue  \
# 271  250/18614  6.861431e-42  1.508829e-38  1.114441e-38
# ...

# %%
df_np2=df[df['Cluster']=='NP2'].iloc[:10,:]
df_np3=df[df['Cluster']=='NP3'].iloc[:10,:]
df_np4=df[df['Cluster']=='NP4'].iloc[:10,:]
df_np5=df[df['Cluster']=='NP5'].iloc[:10,:]

# %%
df_dd
# Out:
#   Cluster          ID                                        Description  \
# 0      DD  GO:0006956                              complement activation
# 1      DD  GO:0006959                            humoral immune response
# 2      DD  GO:0006958           complement activation, classical pathway
# 3      DD  GO:0002455  humoral immune response mediated by circulatin...
# 4      DD  GO:0002253                      activation of immune response
# 5      DD  GO:0042730                                       fibrinolysis
# 6      DD  GO:0030195           negative regulation of blood coagulation
# 7      DD  GO:0002526                        acute inflammatory response
# 8      DD  GO:1900047                  negative regulation of hemostasis
# 9      DD  GO:0050819                 negative regulation of coagulation
#
#   GeneRatio    BgRatio        pvalue      p.adjust        qvalue  \
# 0    25/137   58/18614  6.670401e-39  1.260039e-35  1.013901e-35
# ...

# %% [markdown]
# #  process for radar chart

# %%
df_radar=pd.read_excel(r'F:\\Seer_project\\test.xlsx',sheet_name='Sheet1')
df_radar.set_index('Unnamed: 0',inplace=True)

# %%
df_radar
# Out:
#                CV  Biomarkers  peptide ID  protein ID  Median intensity   \
# Unnamed: 0
# DD          14.86          30       725.0       212.0          17.442438
# NP1         17.63          33       807.0       207.6          17.112451
# NP2         16.52          39      1024.0       278.0          17.010393
# NP3         13.79          34      1085.3       265.0          17.677678
# NP4         21.36          34       920.6       238.3          17.361636
# NP5         20.75          34      1126.0       278.0          17.457459
#
#             linearity
# Unnamed: 0
# DD               0.836
# NP1              0.856
# NP2              0.894
# NP3              0.885
# NP4              0.948
# NP5              0.907

# %%
# apply standard scaler to the ratar dataframe 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_radar)

# Convert scaled data back to DataFrame for better visualization and to retain column names
normalized_df_radar = pd.DataFrame(scaled_data, columns=df_radar.columns,index=df_radar.index)
normalized_df_radar
# Out:
#                   CV  Biomarkers  peptide ID  protein ID  Median intensity   \
# Unnamed: 0
# DD         -0.936190   -1.511858   -1.534644   -1.183065           0.442325
# NP1         0.051713   -0.377964   -0.970293   -1.334021          -1.035584
# NP2        -0.344161    1.889822    0.523171    1.081283          -1.492670
# NP3        -1.317799    0.000000    0.945058    0.635275           1.495891
# NP4         1.381995    0.000000   -0.188461   -0.280756           0.080438
# NP5         1.164442    0.000000    1.225169    1.081283           0.509599
#
#             linearity
# Unnamed: 0
# DD           -1.439139
# NP1          -0.882053
# NP2           0.176411
# NP3          -0.074278
# NP4           1.680543
# NP5           0.538516

# %%
normalized_df_radar.to_csv(r'F:\\Seer_project\\R_data\\radar.csv')
